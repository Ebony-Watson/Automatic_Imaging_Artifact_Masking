# %% [markdown]
# # Training Artifact Classification Model

# %%
import os
import math
import numpy as np
import pandas as pd
import keras
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import roc_curve,auc

from utils.resnet import DataGenerator, build_ResNet

# %% [markdown]
# ## Prepare datasets

# %%
traindir_name = './data/artifact_classifier/train/'
testdir_name = './data/artifact_classifier/test/'

# %%
width = 576
height = 576

label_to_class = {
    'clean':0,
    'artifact':1
}

class_to_label = {v: k for k, v in label_to_class.items()}

train_params = {'dim': (width,height),
          'batch_size': 12,
          'n_classes': len(label_to_class),
          'n_channels': 3,
          'shuffle': True,
          'Augment': True,
           'PATH': traindir_name}

val_params = {'dim': (width,height),
          'batch_size': 12,
          'n_classes': len(label_to_class),
          'n_channels': 3,
          'shuffle': False,
          'Augment':False,
          'PATH': traindir_name}

test_params = {'dim': (width,height),
          'batch_size': 1,
          'n_classes': len(label_to_class),
          'n_channels': 3,
          'shuffle': False,
          'Augment':False,
          'PATH':testdir_name}

# %%
train_Images = []
train_Classes = []

for label_name in os.listdir(traindir_name):
    cls = label_to_class[label_name]
    for img_name in os.listdir('/'.join([traindir_name, label_name])):
        train_Images.append(label_name + '/' + img_name)
        train_Classes.append(cls)
        
train_Classes =  np.array(train_Classes, dtype=np.float32)
train_Images =  np.array(train_Images)

# %%
test_Images = []
test_Classes = []

for label_name in os.listdir(testdir_name):
    cls = label_to_class[label_name]
    for img_name in os.listdir('/'.join([testdir_name, label_name])):
        test_Images.append(label_name + '/' + img_name)
        test_Classes.append(cls)
        
test_Classes =  np.array(test_Classes, dtype=np.float32)
test_Images =  np.array(test_Images)

# %%
indices_train, indices_val = train_test_split(list(range(len(train_Images))), train_size=0.8, test_size=0.2, shuffle=True)
labels_train = train_Classes[indices_train]
labels_val = train_Classes[indices_val]
labels_test=test_Classes

partition={'train':train_Images[indices_train], 'validation':train_Images[indices_val], 'test':test_Images}

training_generator = DataGenerator(partition['train'], labels_train,**train_params)
validation_generator = DataGenerator(partition['validation'],labels_val, **val_params)
testing_generator = DataGenerator(partition['test'], labels_test,**test_params)

del train_Classes#, test_Classes
del train_Images#, test_Images

# %% [markdown]
# ## Compile and train ResNet model

# %%
epochs = 150
name = 'artifact_classifier_test'
chkpt = f'./weights/{name}_weights.h5'

cp_cb = ModelCheckpoint(filepath = chkpt, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True, mode='auto')
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1,patience=10, min_lr=0)
es_cb = EarlyStopping(monitor='val_loss', patience=25, verbose=1, mode='auto')

model = build_ResNet()

history = model.fit(training_generator, epochs=epochs,
                    validation_data=validation_generator,
                    callbacks=[cp_cb,reduce_lr,es_cb],
                    class_weight={0: 1.0, 1: 1.0},
                    shuffle=True)
# Out:
# Epoch 1/150
# 108/108 [==============================] - ETA: 0s - loss: 0.6925 - accuracy: 0.6813
# Epoch 1: val_loss improved from inf to 1.53650, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 70s 598ms/step - loss: 0.6925 - accuracy: 0.6813 - val_loss: 1.5365 - val_accuracy: 0.5926 - lr: 0.0020
# Epoch 2/150
# 108/108 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.7932
# Epoch 2: val_loss improved from 1.53650 to 0.72966, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 66s 607ms/step - loss: 0.3972 - accuracy: 0.7932 - val_loss: 0.7297 - val_accuracy: 0.3704 - lr: 0.0020
# Epoch 3/150
# 108/108 [==============================] - ETA: 0s - loss: 0.4199 - accuracy: 0.8017
# Epoch 3: val_loss did not improve from 0.72966
# 108/108 [==============================] - 64s 596ms/step - loss: 0.4199 - accuracy: 0.8017 - val_loss: 6.5005 - val_accuracy: 0.6698 - lr: 0.0020
# Epoch 4/150
# 108/108 [==============================] - ETA: 0s - loss: 0.3447 - accuracy: 0.8387
# Epoch 4: val_loss did not improve from 0.72966
# 108/108 [==============================] - 66s 611ms/step - loss: 0.3447 - accuracy: 0.8387 - val_loss: 0.7816 - val_accuracy: 0.5648 - lr: 0.0020
# Epoch 5/150
# 108/108 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8503
# Epoch 5: val_loss improved from 0.72966 to 0.67328, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 63s 579ms/step - loss: 0.3000 - accuracy: 0.8503 - val_loss: 0.6733 - val_accuracy: 0.5247 - lr: 0.0020
# Epoch 6/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9020
# Epoch 6: val_loss improved from 0.67328 to 0.44335, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 594ms/step - loss: 0.2304 - accuracy: 0.9020 - val_loss: 0.4434 - val_accuracy: 0.7685 - lr: 0.0020
# Epoch 7/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2550 - accuracy: 0.8843
# Epoch 7: val_loss improved from 0.44335 to 0.33677, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 591ms/step - loss: 0.2550 - accuracy: 0.8843 - val_loss: 0.3368 - val_accuracy: 0.8765 - lr: 0.0020
# Epoch 8/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2384 - accuracy: 0.8881
# Epoch 8: val_loss improved from 0.33677 to 0.25562, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 63s 583ms/step - loss: 0.2384 - accuracy: 0.8881 - val_loss: 0.2556 - val_accuracy: 0.9198 - lr: 0.0020
# Epoch 9/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2428 - accuracy: 0.8927
# Epoch 9: val_loss did not improve from 0.25562
# 108/108 [==============================] - 63s 587ms/step - loss: 0.2428 - accuracy: 0.8927 - val_loss: 0.2824 - val_accuracy: 0.8765 - lr: 0.0020
# Epoch 10/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2296 - accuracy: 0.9059
# Epoch 10: val_loss improved from 0.25562 to 0.13751, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 588ms/step - loss: 0.2296 - accuracy: 0.9059 - val_loss: 0.1375 - val_accuracy: 0.9753 - lr: 0.0020
# Epoch 11/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9005
# Epoch 11: val_loss did not improve from 0.13751
# 108/108 [==============================] - 65s 598ms/step - loss: 0.2211 - accuracy: 0.9005 - val_loss: 0.1896 - val_accuracy: 0.9537 - lr: 0.0020
# Epoch 12/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9213
# Epoch 12: val_loss improved from 0.13751 to 0.09685, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 65s 597ms/step - loss: 0.1871 - accuracy: 0.9213 - val_loss: 0.0969 - val_accuracy: 0.9691 - lr: 0.0020
# Epoch 13/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9144
# Epoch 13: val_loss did not improve from 0.09685
# 108/108 [==============================] - 63s 584ms/step - loss: 0.2136 - accuracy: 0.9144 - val_loss: 0.1642 - val_accuracy: 0.9383 - lr: 0.0020
# Epoch 14/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9190
# Epoch 14: val_loss did not improve from 0.09685
# 108/108 [==============================] - 65s 597ms/step - loss: 0.1932 - accuracy: 0.9190 - val_loss: 0.3770 - val_accuracy: 0.8519 - lr: 0.0020
# Epoch 15/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9136
# Epoch 15: val_loss did not improve from 0.09685
# 108/108 [==============================] - 64s 592ms/step - loss: 0.1963 - accuracy: 0.9136 - val_loss: 0.1418 - val_accuracy: 0.9784 - lr: 0.0020
# Epoch 16/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.9136
# Epoch 16: val_loss did not improve from 0.09685
# 108/108 [==============================] - 65s 599ms/step - loss: 0.2121 - accuracy: 0.9136 - val_loss: 0.1168 - val_accuracy: 0.9784 - lr: 0.0020
# Epoch 17/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2433 - accuracy: 0.8912
# Epoch 17: val_loss did not improve from 0.09685
# 108/108 [==============================] - 64s 594ms/step - loss: 0.2433 - accuracy: 0.8912 - val_loss: 0.2186 - val_accuracy: 0.9198 - lr: 0.0020
# Epoch 18/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9205
# Epoch 18: val_loss did not improve from 0.09685
# 108/108 [==============================] - 63s 581ms/step - loss: 0.1913 - accuracy: 0.9205 - val_loss: 0.1165 - val_accuracy: 0.9722 - lr: 0.0020
# Epoch 19/150
# 108/108 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9120
# Epoch 19: val_loss did not improve from 0.09685
# 108/108 [==============================] - 64s 592ms/step - loss: 0.2112 - accuracy: 0.9120 - val_loss: 0.4325 - val_accuracy: 0.7809 - lr: 0.0020
# Epoch 20/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1906 - accuracy: 0.9190
# Epoch 20: val_loss did not improve from 0.09685
# 108/108 [==============================] - 63s 586ms/step - loss: 0.1906 - accuracy: 0.9190 - val_loss: 0.1811 - val_accuracy: 0.9537 - lr: 0.0020
# Epoch 21/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1832 - accuracy: 0.9228
# Epoch 21: val_loss did not improve from 0.09685
# 108/108 [==============================] - 64s 588ms/step - loss: 0.1832 - accuracy: 0.9228 - val_loss: 0.6607 - val_accuracy: 0.6605 - lr: 0.0020
# Epoch 22/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9205
# Epoch 22: val_loss did not improve from 0.09685
# 108/108 [==============================] - 64s 591ms/step - loss: 0.1940 - accuracy: 0.9205 - val_loss: 0.0975 - val_accuracy: 0.9938 - lr: 0.0020
# Epoch 23/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9252
# Epoch 23: val_loss improved from 0.09685 to 0.08071, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 595ms/step - loss: 0.1760 - accuracy: 0.9252 - val_loss: 0.0807 - val_accuracy: 1.0000 - lr: 2.0000e-04
# Epoch 24/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1424 - accuracy: 0.9475
# Epoch 24: val_loss improved from 0.08071 to 0.07525, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 593ms/step - loss: 0.1424 - accuracy: 0.9475 - val_loss: 0.0752 - val_accuracy: 0.9938 - lr: 2.0000e-04
# Epoch 25/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1568 - accuracy: 0.9383
# Epoch 25: val_loss did not improve from 0.07525
# 108/108 [==============================] - 63s 584ms/step - loss: 0.1568 - accuracy: 0.9383 - val_loss: 0.0753 - val_accuracy: 0.9907 - lr: 2.0000e-04
# Epoch 26/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.9336
# Epoch 26: val_loss did not improve from 0.07525
# 108/108 [==============================] - 64s 595ms/step - loss: 0.1684 - accuracy: 0.9336 - val_loss: 0.0888 - val_accuracy: 0.9846 - lr: 2.0000e-04
# Epoch 27/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1421 - accuracy: 0.9429
# Epoch 27: val_loss did not improve from 0.07525
# 108/108 [==============================] - 64s 594ms/step - loss: 0.1421 - accuracy: 0.9429 - val_loss: 0.0865 - val_accuracy: 0.9846 - lr: 2.0000e-04
# Epoch 28/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1482 - accuracy: 0.9437
# Epoch 28: val_loss improved from 0.07525 to 0.07256, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 591ms/step - loss: 0.1482 - accuracy: 0.9437 - val_loss: 0.0726 - val_accuracy: 0.9938 - lr: 2.0000e-04
# Epoch 29/150
# 108/108 [==============================] - ETA: 0s - loss: 0.
150
# 108/108 [==============================] - ETA: 0s - loss: 0.1045 - accuracy: 0.9576
# Epoch 44: val_loss did not improve from 0.06385
# 108/108 [==============================] - 64s 589ms/step - loss: 0.1045 - accuracy: 0.9576 - val_loss: 0.0733 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 45/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9483
# Epoch 45: val_loss did not improve from 0.06385
# 108/108 [==============================] - 63s 589ms/step - loss: 0.1188 - accuracy: 0.9483 - val_loss: 0.0706 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 46/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1050 - accuracy: 0.9583
# Epoch 46: val_loss did not improve from 0.06385
# 108/108 [==============================] - 63s 582ms/step - loss: 0.1050 - accuracy: 0.9583 - val_loss: 0.0668 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 47/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1033 - accuracy: 0.9630
# Epoch 47: val_loss improved from 0.06385 to 0.06368, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 587ms/step - loss: 0.1033 - accuracy: 0.9630 - val_loss: 0.0637 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 48/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1193 - accuracy: 0.9498
# Epoch 48: val_loss did not improve from 0.06368
# 108/108 [==============================] - 65s 599ms/step - loss: 0.1193 - accuracy: 0.9498 - val_loss: 0.0690 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 49/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1114 - accuracy: 0.9576
# Epoch 49: val_loss did not improve from 0.06368
# 108/108 [==============================] - 64s 588ms/step - loss: 0.1114 - accuracy: 0.9576 - val_loss: 0.0688 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 50/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9645
# Epoch 50: val_loss did not improve from 0.06368
# 108/108 [==============================] - 63s 584ms/step - loss: 0.1082 - accuracy: 0.9645 - val_loss: 0.0666 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 51/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1091 - accuracy: 0.9568
# Epoch 51: val_loss did not improve from 0.06368
# 108/108 [==============================] - 63s 582ms/step - loss: 0.1091 - accuracy: 0.9568 - val_loss: 0.0687 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 52/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1091 - accuracy: 0.9522
# Epoch 52: val_loss did not improve from 0.06368
# 108/108 [==============================] - 64s 596ms/step - loss: 0.1091 - accuracy: 0.9522 - val_loss: 0.0660 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 53/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0824 - accuracy: 0.9730
# Epoch 53: val_loss did not improve from 0.06368
# 108/108 [==============================] - 64s 594ms/step - loss: 0.0824 - accuracy: 0.9730 - val_loss: 0.0685 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 54/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9460
# Epoch 54: val_loss improved from 0.06368 to 0.06187, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 596ms/step - loss: 0.1174 - accuracy: 0.9460 - val_loss: 0.0619 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 55/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9545
# Epoch 55: val_loss improved from 0.06187 to 0.05929, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 64s 594ms/step - loss: 0.1185 - accuracy: 0.9545 - val_loss: 0.0593 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 56/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9606
# Epoch 56: val_loss did not improve from 0.05929
# 108/108 [==============================] - 63s 586ms/step - loss: 0.1095 - accuracy: 0.9606 - val_loss: 0.0665 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 57/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9606
# Epoch 57: val_loss did not improve from 0.05929
# 108/108 [==============================] - 64s 592ms/step - loss: 0.1049 - accuracy: 0.9606 - val_loss: 0.0648 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 58/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0987 - accuracy: 0.9630
# Epoch 58: val_loss did not improve from 0.05929
# 108/108 [==============================] - 63s 588ms/step - loss: 0.0987 - accuracy: 0.9630 - val_loss: 0.0636 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 59/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9576
# Epoch 59: val_loss did not improve from 0.05929
# 108/108 [==============================] - 65s 598ms/step - loss: 0.1059 - accuracy: 0.9576 - val_loss: 0.0611 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 60/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9637
# Epoch 60: val_loss did not improve from 0.05929
# 108/108 [==============================] - 64s 595ms/step - loss: 0.0906 - accuracy: 0.9637 - val_loss: 0.0629 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch 61/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9653
# Epoch 61: val_loss improved from 0.05929 to 0.05924, saving model to ./weights\artifact_classifier_test_weights.h5
# 108/108 [==============================] - 65s 600ms/step - loss: 0.0946 - accuracy: 0.9653 - val_loss: 0.0592 - val_accuracy: 0.9846 - lr: 2.0000e-05
# Epoch
150
# 108/108 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9622
# Epoch 81: val_loss did not improve from 0.05131
# 108/108 [==============================] - 64s 593ms/step - loss: 0.0937 - accuracy: 0.9622 - val_loss: 0.0529 - val_accuracy: 0.9846 - lr: 2.0000e-06
# Epoch 82/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0931 - accuracy: 0.9653
# Epoch 82: val_loss did not improve from 0.05131
# 108/108 [==============================] - 65s 599ms/step - loss: 0.0931 - accuracy: 0.9653 - val_loss: 0.0535 - val_accuracy: 0.9815 - lr: 2.0000e-06
# Epoch 83/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0877 - accuracy: 0.9676
# Epoch 83: val_loss did not improve from 0.05131
# 108/108 [==============================] - 64s 592ms/step - loss: 0.0877 - accuracy: 0.9676 - val_loss: 0.0522 - val_accuracy: 0.9846 - lr: 2.0000e-06
# Epoch 84/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9630
# Epoch 84: val_loss did not improve from 0.05131
# 108/108 [==============================] - 63s 587ms/step - loss: 0.0924 - accuracy: 0.9630 - val_loss: 0.0543 - val_accuracy: 0.9815 - lr: 2.0000e-06
# Epoch 85/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9637
# Epoch 85: val_loss did not improve from 0.05131
# 108/108 [==============================] - 63s 586ms/step - loss: 0.0958 - accuracy: 0.9637 - val_loss: 0.0521 - val_accuracy: 0.9846 - lr: 2.0000e-06
# Epoch 86/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0928 - accuracy: 0.9691
# Epoch 86: val_loss did not improve from 0.05131
# 108/108 [==============================] - 63s 585ms/step - loss: 0.0928 - accuracy: 0.9691 - val_loss: 0.0530 - val_accuracy: 0.9846 - lr: 2.0000e-06
# Epoch 87/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9637
# Epoch 87: val_loss did not improve from 0.05131
# 108/108 [==============================] - 63s 582ms/step - loss: 0.0920 - accuracy: 0.9637 - val_loss: 0.0556 - val_accuracy: 0.9846 - lr: 2.0000e-06
# Epoch 88/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9707
# Epoch 88: val_loss did not improve from 0.05131
# 108/108 [==============================] - 64s 596ms/step - loss: 0.0839 - accuracy: 0.9707 - val_loss: 0.0552 - val_accuracy: 0.9815 - lr: 2.0000e-06
# Epoch 89/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9591
# Epoch 89: val_loss did not improve from 0.05131
# 108/108 [==============================] - 64s 589ms/step - loss: 0.1080 - accuracy: 0.9591 - val_loss: 0.0557 - val_accuracy: 0.9815 - lr: 2.0000e-06
# Epoch 90/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9614
# Epoch 90: val_loss did not improve from 0.05131
# 108/108 [==============================] - 64s 597ms/step - loss: 0.0947 - accuracy: 0.9614 - val_loss: 0.0528 - val_accuracy: 0.9846 - lr: 2.0000e-07
# Epoch 91/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9583
# Epoch 91: val_loss did not improve from 0.05131
# 108/108 [==============================] - 65s 598ms/step - loss: 0.1005 - accuracy: 0.9583 - val_loss: 0.0527 - val_accuracy: 0.9846 - lr: 2.0000e-07
# Epoch 92/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9676
# Epoch 92: val_loss did not improve from 0.05131
# 108/108 [==============================] - 63s 586ms/step - loss: 0.0942 - accuracy: 0.9676 - val_loss: 0.0515 - val_accuracy: 0.9846 - lr: 2.0000e-07
# Epoch 93/150
# 108/108 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9660
# Epoch 93: val_loss did not improve from 0.05131
# 108/108 [==============================] - 64s 595ms/step - loss: 0.1095 - accuracy: 0.9660 - val_loss: 0.0553 - val_accuracy: 0.9815 - lr: 2.0000e-07
# Epoch 94/150
# 108/108 [==============================] - ETA: 0s - loss: 0.0848 - accuracy: 0.9676
# Epoch 94: val_loss did not improve from 0.05131
# 108/108 [==============================] - 63s 582ms/step - loss: 0.0848 - accuracy: 0.9676 - val_loss: 0.0551 - val_accuracy: 0.9815 - lr: 2.0000e-07
# Epoch 94: early stopping

# %% [markdown]
# ### Visualise training

# %%
df = pd.DataFrame(history.history)
df.plot(figsize=(8,5),ylim=(0,1.05))
plt.savefig(f'./results/{name}_training.png')
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
results = model.evaluate(testing_generator)
print("test loss, test acc:", results)
# Out:
# 403/403 [==============================] - 6s 15ms/step - loss: 0.0517 - accuracy: 0.9801
# test loss, test acc: [0.05166829377412796, 0.9801489114761353]

# %%
# Breakdown of performance
pred = model.predict(testing_generator)
y_pred_bool = (pred>0.5).astype('int32')
y_test = keras.utils.to_categorical(labels_test, num_classes=2)

print(classification_report(y_test, y_pred_bool))
# Out:
# 403/403 [==============================] - 6s 14ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       139
#            1       1.00      0.97      0.98       264
#
#    micro avg       0.98      0.98      0.98       403
#    macro avg       0.97      0.98      0.98       403
# weighted avg       0.98      0.98      0.98       403
#  samples avg       0.98      0.98      0.98       403

# %% [markdown]
# ### Visualise ROC curve

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test.ravel(), pred.ravel())
auc_keras = auc(fpr_keras, tpr_keras)

# %%
plt.figure(1)
plt.plot(fpr_keras, tpr_keras, label='ROC (AUC = {:.3f})'.format(auc_keras), c='orange', alpha=0.8)
sns.scatterplot(x=fpr_keras, y=tpr_keras, alpha=1, color='orange', s=15,edgecolor="none")
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.plot([0, 1], [0, 1], 'k--', c= 'gray')
plt.title('ROC curve')
plt.legend(loc='best')
plt.gca().spines[['top', 'right']].set_visible(False)
plt.savefig(f'./results/{name}_ROC.png', dpi=300, transparent=True,bbox_inches='tight')
plt.show()
# Out:
# C:\Users\uqewats6\AppData\Local\Temp\ipykernel_25080\1310635740.py:6: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot([0, 1], [0, 1], 'k--', c= 'gray')

# %% [markdown]
# ### Explore any samples that were misclassified

# %%
indices = [i for i in range(len(y_test)) if (y_test[i]!=y_pred_bool[i]).all()]

imgs = [cv2.imread(os.path.join(testdir_name, image), -1) for image in test_Images[indices]]
name = [image.split('/')[0] for image in test_Images[indices]]

n_plots = len(indices)
n_cols = 4
n_rows = (n_plots + 1) // n_cols

_, axs = plt.subplots(n_rows, n_cols, figsize=(12, 6))
axs = axs.flatten()
for img, nm, ax in zip(imgs, name, axs):
    ax.imshow(img, cmap='gray')
    ax.set_title(nm) #show what the true class should be
plt.show()

# %% [markdown]
# # Generate data subset for Score-CAM/UNET

# %% [markdown]
# Use trained ResNet to classify all ground-truth artifact images from the train/test set. The correctly classified artifact images will then be used to generate training labels for segmentation model using Score-CAM.ipynb.

# %%
import shutil
from utils.resnet import DataGenerator_Pred

# %%
data_dir = './data/artifact_classifier/all_artifacts/'

name = 'artifact_classifier_test'

params = {'dim': (width,height),
          'batch_size': 1,
          'n_channels': 3,
          'shuffle': False,
          'PATH':data_dir}

# %%
images = np.array(os.listdir(data_dir))
partition={'data':images}
data_generator = DataGenerator_Pred(partition['data'], **params)

# %%
model = build_ResNet()
model.load_weights(f'./weights/{name}_weights.h5') 

pred = model.predict(data_generator)
pred_bool = (pred>0.5).astype('int32')
# Out:
# 1327/1327 [==============================] - 21s 15ms/step

# %%
artifact = [im for im, pred_class in zip(images, pred_bool) if pred_class[1] == 1]
clean = [im for im, pred_class in zip(images, pred_bool) if pred_class[1] == 0]

print(len(clean),len(artifact))
# Out:
# 27 1300

# %%
dest_path = './data/Score-CAM/images/'
os.makedirs(dest_path, exist_ok=True)

for file in artifact:
    shutil.move(os.path.join(data_dir, file), dest_path)
